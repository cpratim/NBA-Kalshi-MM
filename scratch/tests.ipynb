# %%
import os
from pipeline.pipeline import Pipeline

# %%
pipeline = Pipeline()
X, y = pipeline.load_dataset()
# Out:
#  11%|█▏        | 792/7039 [00:51<06:44, 15.44it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 pipeline = Pipeline()
# ----> 2 X, y = pipeline.load_dataset()
#
# File ~/Documents/nba-kalshi-mm/src/pipeline/pipeline.py:374, in Pipeline.load_dataset(self)
#     372 if not file.endswith('.pkl'):
#     373     continue
# --> 374 with open(os.path.join(dataset_dir, file), 'rb') as f:
#     375     data = pickle.load(f)
#     377 home_X = data['home']['pbp']
#
# KeyboardInterrupt:
